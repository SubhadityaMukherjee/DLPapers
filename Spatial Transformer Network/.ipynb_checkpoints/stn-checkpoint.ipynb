# %%
from fastai import *
from fastai.vision import *
import torch.onnx
from torch.autograd import Variable

import netron

# %%
import os

os.environ["TORCH_HOME"] = "/media/subhaditya/DATA/COSMO/Datasets-Useful"

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="torch.nn.functional")

# %%
path = untar_data(URLs.MNIST)

# %%
data = (
    (
        ImageList.from_folder(path)
        .split_by_rand_pct()
        .label_from_folder()
        .transform(get_transforms(), size=32)
    )
    .databunch(bs=64)
    .normalize(imagenet_stats)
)

# %%
data.show_batch(4)

# %%
data.c
# Out:
# 10

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (56000 items)
# x: ImageList
# Image (3, 32, 32),Image (3, 32, 32),Image (3, 32, 32),Image (3, 32, 32),Image (3, 32, 32)
# y: CategoryList
# 1,1,1,1,1
# Path: /home/subhaditya/.fastai/data/mnist_png;
#
# Valid: LabelList (14000 items)
# x: ImageList
# Image (3, 32, 32),Image (3, 32, 32),Image (3, 32, 32),Image (3, 32, 32),Image (3, 32, 32)
# y: CategoryList
# 8,9,0,8,3
# Path: /home/subhaditya/.fastai/data/mnist_png;
#
# Test: None

# %% [markdown]
# # STN

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.conv1 = nn.Conv2d(3, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.dr = nn.Dropout2d()
        self.fc1 = nn.Linear(500, 50)
        self.fc2 = nn.Linear(50, 100)

        # localization net
        self.local = nn.Sequential(
            nn.Conv2d(3, 8, kernel_size=7),
            nn.MaxPool2d(2, stride=2),
            nn.ReLU(inplace=True),
            nn.Conv2d(8, 10, kernel_size=5),
            nn.MaxPool2d(2, stride=2),
            nn.ReLU(inplace=True),
        )
        # Regressor
        self.fc_loc = nn.Sequential(
            nn.Linear(160, 32), nn.ReLU(inplace=True), nn.Linear(32, 3 * 2)
        )
        
        #init fn
        self.fc_loc[2].weight.data.zero_()
        self.fc_loc[2].bias.data.copy_(torch.tensor([1,0,0,0,1,0],dtype = torch.float))
    
    # stn main forward
    def stn(self, x):
        xs = self.local(x)
        xs = xs.view(-1, 160)
        theta = self.fc_loc(xs)
        theta = theta.view(-1, 2, 3)
        grid = F.affine_grid(theta, x.size())
        x = F.grid_sample(x, grid)
        return x

    def forward(self, x):
        x = self.stn(x)
        x = F.relu(F.max_pool2d(self.conv1(x),2))
        x = F.relu(F.max_pool2d(self.dr(self.conv2(x)),2))
        x = x.view(-1, 500)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return x

# %%
learn = None
gc.collect()
# Out:
# 617

# %%
learn = Learner(
    data,
    Model(),
    metrics=[accuracy, error_rate],
    opt_func=optim.SGD,
    callback_fns=ShowGraph,
)

# %%
learn.summary()
# Out:
# Model
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# Conv2d               [10, 28, 28]         760        True
# ______________________________________________________________________
# Conv2d               [20, 10, 10]         5,020      True
# ______________________________________________________________________
# Dropout2d            [20, 10, 10]         0          False
# ______________________________________________________________________
# Linear               [50]                 25,050     True
# ______________________________________________________________________
# Linear               [100]                5,100      True
# ______________________________________________________________________
# Conv2d               [8, 26, 26]          1,184      True
# ______________________________________________________________________
# MaxPool2d            [8, 13, 13]          0          False
# ______________________________________________________________________
# ReLU                 [8, 13, 13]          0          False
# ______________________________________________________________________
# Conv2d               [10, 9, 9]           2,010      True
# ______________________________________________________________________
# MaxPool2d            [10, 4, 4]           0          False
# ______________________________________________________________________
# ReLU                 [10, 4, 4]           0          False
# ______________________________________________________________________
# Linear               [32]                 5,152      True
# ______________________________________________________________________
# ReLU                 [32]                 0          False
# ______________________________________________________________________
# Linear               [6]                  198        True
# ______________________________________________________________________
#
# Total params: 44,474
# Total trainable params: 44,474
# Total non-trainable params: 0
# Optimized with GD'
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='98' class='' max='875', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       11.20% [98/875 00:03<00:26 4.2139]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(10, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.973503</td>
#       <td>0.513259</td>
#       <td>0.817929</td>
#       <td>0.182071</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.745889</td>
#       <td>0.307482</td>
#       <td>0.897143</td>
#       <td>0.102857</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.661999</td>
#       <td>0.193469</td>
#       <td>0.941786</td>
#       <td>0.058214</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.530336</td>
#       <td>0.153940</td>
#       <td>0.952143</td>
#       <td>0.047857</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.501817</td>
#       <td>0.154952</td>
#       <td>0.950214</td>
#       <td>0.049786</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.457528</td>
#       <td>0.145724</td>
#       <td>0.953786</td>
#       <td>0.046214</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.427211</td>
#       <td>0.153140</td>
#       <td>0.952429</td>
#       <td>0.047571</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.372494</td>
#       <td>0.103022</td>
#       <td>0.967357</td>
#       <td>0.032643</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.317279</td>
#       <td>0.098608</td>
#       <td>0.969643</td>
#       <td>0.030357</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.300593</td>
#       <td>0.085140</td>
#       <td>0.974857</td>
#       <td>0.025143</td>
#       <td>00:12</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(1, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.351611</td>
#       <td>0.094232</td>
#       <td>0.969643</td>
#       <td>0.030357</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>

# %%
def convert_image_np(inp):
    """Convert a Tensor to numpy image."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    return inp

# %%
import torchvision

# %%
data.valid_dl.dl.dataset.x.get(2).data.unsqueeze(0).shape
# Out:
# torch.Size([1, 3, 28, 28])

# %%
with torch.no_grad():
        
        data2 = next(iter(data.train_dl.dl))[0].to('cuda')
#         data2 = next(iter(data.valid_dl.dl))[1].to('cuda')

        input_tensor = data2.cpu()
        transformed_input_tensor = learn.model.stn(data2).cpu()

        in_grid = convert_image_np(
            torchvision.utils.make_grid(input_tensor))

        out_grid = convert_image_np(
            torchvision.utils.make_grid(transformed_input_tensor))

        # Plot the results side-by-side
        f, axarr = plt.subplots(1, 2)
        axarr[0].imshow(in_grid)
        axarr[0].set_title('Dataset Images')

        axarr[1].imshow(out_grid)
        axarr[1].set_title('Transformed Images')
