# %%
from fastai import *
from fastai.vision import *
import torch.onnx
from torch.autograd import Variable

import netron

# %%
import os

os.environ["TORCH_HOME"] = "/media/subhaditya/DATA/COSMO/Datasets-Useful"

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="torch.nn.functional")

# %%
path = untar_data(URLs.CIFAR_100)

# %%
data = (
    (
        ImageList.from_folder(path)
        .split_by_rand_pct()
        .label_from_folder()
        .transform(get_transforms(), size=128)
    )
    .databunch(bs=64)
    .normalize(imagenet_stats)
)

# %%
data.show_batch(4)

# %%
data.c
# Out:
# 100

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (48000 items)
# x: ImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: CategoryList
# cloud,cloud,cloud,cloud,cloud
# Path: /home/subhaditya/.fastai/data/cifar100;
#
# Valid: LabelList (12000 items)
# x: ImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: CategoryList
# bicycle,crab,hamster,snake,lawn_mower
# Path: /home/subhaditya/.fastai/data/cifar100;
#
# Test: None

# %% [markdown]
# # STN

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.conv1 = nn.Conv2d(3, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.dr = nn.Dropout2d()
        self.fc1 = nn.Linear(16820, 50)
        self.fc2 = nn.Linear(50, 100)

        # localization net
        self.local = nn.Sequential(
            nn.Conv2d(3, 8, kernel_size=7),
            nn.MaxPool2d(2, stride=2),
            nn.ReLU(inplace=True),
            nn.Conv2d(8, 10, kernel_size=5),
            nn.MaxPool2d(2, stride=2),
            nn.ReLU(inplace=True),
        )
        # Regressor
        self.fc_loc = nn.Sequential(
            nn.Linear(7840, 32), nn.ReLU(inplace=True), nn.Linear(32, 3 * 2)
        )
        
        #init fn
        self.fc_loc[2].weight.data.zero_()
        self.fc_loc[2].bias.data.copy_(torch.tensor([1,0,0,0,1,0],dtype = torch.float))
    
    # stn main forward
    def stn(self, x):
        xs = self.local(x)
        xs = xs.view(-1, 7840)
        theta = self.fc_loc(xs)
        theta = theta.view(-1, 2, 3)
        grid = F.affine_grid(theta, x.size())
        x = F.grid_sample(x, grid)
        return x

    def forward(self, x):
        x = self.stn(x)
        x = F.relu(F.max_pool2d(self.conv1(x),2))
        x = F.relu(F.max_pool2d(self.dr(self.conv2(x)),2))
        x = x.view(-1, 16820)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return x

# %%
learn = None
gc.collect()
# Out:
# 35372

# %%
learn = Learner(
    data,
    Model(),
    metrics=[accuracy, error_rate],
    opt_func=AdamW,
    callback_fns=ShowGraph,
)

# %%
learn.summary()
# Out:
# Model
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# Conv2d               [10, 124, 124]       760        True
# ______________________________________________________________________
# Conv2d               [20, 58, 58]         5,020      True
# ______________________________________________________________________
# Dropout2d            [20, 58, 58]         0          False
# ______________________________________________________________________
# Linear               [50]                 841,050    True
# ______________________________________________________________________
# Linear               [100]                5,100      True
# ______________________________________________________________________
# Conv2d               [8, 122, 122]        1,184      True
# ______________________________________________________________________
# MaxPool2d            [8, 61, 61]          0          False
# ______________________________________________________________________
# ReLU                 [8, 61, 61]          0          False
# ______________________________________________________________________
# Conv2d               [10, 57, 57]         2,010      True
# ______________________________________________________________________
# MaxPool2d            [10, 28, 28]         0          False
# ______________________________________________________________________
# ReLU                 [10, 28, 28]         0          False
# ______________________________________________________________________
# Linear               [32]                 250,912    True
# ______________________________________________________________________
# ReLU                 [32]                 0          False
# ______________________________________________________________________
# Linear               [6]                  198        True
# ______________________________________________________________________
#
# Total params: 1,106,234
# Total trainable params: 1,106,234
# Total non-trainable params: 0
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='96' class='' max='750', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       12.80% [96/750 00:03<00:25 4.6839]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(5, 1e-6)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.613793</td>
#       <td>4.609200</td>
#       <td>0.006750</td>
#       <td>0.993250</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.606634</td>
#       <td>4.604369</td>
#       <td>0.008417</td>
#       <td>0.991583</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.602910</td>
#       <td>4.599808</td>
#       <td>0.011417</td>
#       <td>0.988583</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.601257</td>
#       <td>4.597255</td>
#       <td>0.012083</td>
#       <td>0.987917</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.599485</td>
#       <td>4.596813</td>
#       <td>0.012333</td>
#       <td>0.987667</td>
#       <td>00:29</td>
#     </tr>
#   </tbody>
# </table>
