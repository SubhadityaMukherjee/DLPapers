# %%
# %matplotlib inline
from fastai.vision import *
from fastai import *
from torch.autograd import Variable

import os

os.environ["TORCH_HOME"] = "/media/subhaditya/DATA/COSMO/Datasets-Useful"

# %%
# path =Path('/media/subhaditya/DATA/PLAYGROUND/randomDL/ganAgain/data')

# %%
path = untar_data(URLs.FLOWERS);path.ls()
# Out:
# [PosixPath('/home/subhaditya/.fastai/data/oxford-102-flowers/test.txt'),
#  PosixPath('/home/subhaditya/.fastai/data/oxford-102-flowers/jpg'),
#  PosixPath('/home/subhaditya/.fastai/data/oxford-102-flowers/valid.txt'),
#  PosixPath('/home/subhaditya/.fastai/data/oxford-102-flowers/train.txt')]

# %%
data = (
    (
        ImageList.from_folder(path)
        .split_by_rand_pct()
        .label_from_folder()
        .transform(get_transforms(), size=28)
    )
    .databunch(bs=128)
    .normalize(imagenet_stats)
)
# data = ImageDataBunch.from_folder(path, ds_tfms=get_transforms(), size=28,valid_pct=0)

# %%
data.show_batch()

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (6552 items)
# x: ImageList
# Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28)
# y: CategoryList
# jpg,jpg,jpg,jpg,jpg
# Path: /home/subhaditya/.fastai/data/oxford-102-flowers;
#
# Valid: LabelList (1637 items)
# x: ImageList
# Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28)
# y: CategoryList
# jpg,jpg,jpg,jpg,jpg
# Path: /home/subhaditya/.fastai/data/oxford-102-flowers;
#
# Test: None

# %%
class SRCNN(nn.Module):
    def __init__(self):
        super(SRCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=9, padding=4)
        self.relu1 = nn.ReLU()
        self.conv2 = nn.Conv2d(64, 32, kernel_size=1, padding=0)
        self.relu2 = nn.ReLU()
        self.conv3 = nn.Conv2d(32, 3, kernel_size=5, padding=2)
#         self.fc1 = nn.Linear(3, )

    def forward(self, x):
        print(x.shape)
        out = self.conv1(x)
        out = self.relu1(out)
        out = self.conv2(out)
        out = self.relu2(out)
        out = self.conv3(out)
        print(out.shape)
#         out = out.view(28, 28, 128)
#         print(out.shape)

        return out

# %%
srcnn = SRCNN().cuda()
criterion = nn.MSELoss().cuda()

optimizer = optim.Adam(srcnn.parameters(),lr=3e-2)

# %%
training_data_loader = data.train_dl.dl

# %%
training_data_loader.
# Out:
# 128

# %%
def train(epoch):
    epoch_loss = 0
    for iteration, batch in enumerate(training_data_loader, 1):
        input, target = Variable(batch[0]), Variable(batch[1])
#         if use_cuda:
        input = input.cuda()
        target = target.cuda()

        optimizer.zero_grad()
        print ("input shape = " , input.shape)
        print ("target shape = ", target.shape)
        model_out = srcnn(input)
        #print ("model_out shape =" , model_out.shape)
        loss = criterion(model_out, target)
        epoch_loss += loss.data[0]
        loss.backward()
        optimizer.step()

        print("===> Epoch[{}]({}/{}): Loss: {:.4f}".format(epoch, iteration, len(training_data_loader), loss.data[0]))

    print("===> Epoch {} Complete: Avg. Loss: {:.4f}".format(epoch, epoch_loss / len(training_data_loader)))

# %%
train(1)
# Out:
# input shape =  torch.Size([128, 3, 28, 28])
# target shape =  torch.Size([128])
# torch.Size([128, 3, 28, 28])
# torch.Size([128, 3, 28, 28])
# /home/subhaditya/anaconda3/lib/python3.7/site-packages/torch/nn/modules/loss.py:431: UserWarning: Using a target size (torch.Size([128])) that is different to the input size (torch.Size([128, 3, 28, 28])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-151-b888f18a64ca> in <module>
# ----> 1 train(1)
#
# <ipython-input-150-339d8ded112d> in train(epoch)
#      12         model_out = srcnn(input)
#      13         #print ("model_out shape =" , model_out.shape)
# ---> 14         loss = criterion(model_out, target)
#      15         epoch_loss += loss.data[0]
# ...

# %%
import netron

# %%
dummy_input = Variable(torch.randn(1, 3, 28, 28)).cuda()
torch.onnx.export(learn.model, dummy_input, "model.onnx")
netron.start("model.onnx")
# Out:
# Serving 'model.onnx' at http://localhost:8080
