# %%
from fastai import *
from fastai.vision import *
import torch.onnx
from torch.autograd import Variable

import netron

# %%
import os

os.environ["TORCH_HOME"] = "/media/subhaditya/DATA/COSMO/Datasets-Useful"

# %%
path = untar_data(URLs.CIFAR_100)

# %%
data = (
    (
        ImageList.from_folder(path)
        .split_by_rand_pct()
        .label_from_folder()
        .transform(get_transforms(), size=128)
    )
    .databunch(bs=64)
    .normalize(imagenet_stats)
)

# %%
data.show_batch(4)

# %%
data.c
# Out:
# 100

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (48000 items)
# x: ImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: CategoryList
# cloud,cloud,cloud,cloud,cloud
# Path: /home/subhaditya/.fastai/data/cifar100;
#
# Valid: LabelList (12000 items)
# x: ImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: CategoryList
# kangaroo,camel,house,man,tulip
# Path: /home/subhaditya/.fastai/data/cifar100;
#
# Test: None

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
np.floor(((224)+2*2-11)/4)+1
# Out:
# 55.0

# %%
# Out:
# 68.75

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.part1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(3, 2),
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(3, 2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(3, 2),
        )
        self.part2 = nn.AdaptiveAvgPool2d((6, 6))
        self.part3 = nn.Sequential(
            nn.Dropout(),
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(inplace=True),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Linear(4096, 100),
        )

    def forward(self, x):
        x = self.part1(x)
        x = self.part2(x)
        x = torch.flatten(x, 1)
        x = self.part3(x)

        return x

# %%
learn = None
gc.collect()
# Out:
# 65087

# %%
learn = Learner(
    data, Model(), metrics=[accuracy,error_rate], callback_fns=ShowGraph
).to_fp16()

# %%
learn.summary()
# Out:
# Model
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# Conv2d               [64, 31, 31]         23,296     True
# ______________________________________________________________________
# ReLU                 [64, 31, 31]         0          False
# ______________________________________________________________________
# MaxPool2d            [64, 15, 15]         0          False
# ______________________________________________________________________
# Conv2d               [192, 15, 15]        307,392    True
# ______________________________________________________________________
# ReLU                 [192, 15, 15]        0          False
# ______________________________________________________________________
# MaxPool2d            [192, 7, 7]          0          False
# ______________________________________________________________________
# Conv2d               [384, 7, 7]          663,936    True
# ______________________________________________________________________
# ReLU                 [384, 7, 7]          0          False
# ______________________________________________________________________
# Conv2d               [256, 7, 7]          884,992    True
# ______________________________________________________________________
# ReLU                 [256, 7, 7]          0          False
# ______________________________________________________________________
# Conv2d               [256, 7, 7]          590,080    True
# ______________________________________________________________________
# ReLU                 [256, 7, 7]          0          False
# ______________________________________________________________________
# MaxPool2d            [256, 3, 3]          0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [256, 6, 6]          0          False
# ______________________________________________________________________
# Dropout              [9216]               0          False
# ______________________________________________________________________
# Linear               [4096]               37,752,832 True
# ______________________________________________________________________
# ReLU                 [4096]               0          False
# ______________________________________________________________________
# Linear               [4096]               16,781,312 True
# ______________________________________________________________________
# ReLU                 [4096]               0          False
# ______________________________________________________________________
# Linear               [100]                409,700    True
# ______________________________________________________________________
#
# Total params: 57,413,540
# Total trainable params: 57,413,540
# Total non-trainable params: 0
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied
#     MixedPrecision

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='59' class='' max='750', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       7.87% [59/750 00:02<00:32 8.1172]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(5, 1e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.993846</td>
#       <td>3.925035</td>
#       <td>0.084667</td>
#       <td>0.915333</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.450141</td>
#       <td>3.423421</td>
#       <td>0.164167</td>
#       <td>0.835833</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.996476</td>
#       <td>2.949688</td>
#       <td>0.266833</td>
#       <td>0.733167</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.677918</td>
#       <td>2.659980</td>
#       <td>0.322167</td>
#       <td>0.677833</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.515725</td>
#       <td>2.572119</td>
#       <td>0.342417</td>
#       <td>0.657583</td>
#       <td>00:32</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results()

# %%
dummy_input = Variable(torch.randn(1, 3, 224, 224)).cuda().half()
torch.onnx.export(learn.model, dummy_input, "model.onnx")

# %%
netron.start("model.onnx")
# Out:
# Serving 'model.onnx' at http://localhost:8080

# %%
# !rm "model.onnx"
